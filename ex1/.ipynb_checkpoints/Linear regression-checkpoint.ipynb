# %%
"""
A recreation of Ng's ML coursera excercise 1: Linear Regression
"""
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

data = np.loadtxt('ex1data1.txt', delimiter=',')
X = np.matrix(data[:, 0]).T
y = np.matrix(data[:, 1]).T

# %% [markdown]
# # The dataset:

# %%
plt.plot(X, y, 'rx')

# %% [markdown]
# # Performing gradient descent to find the optimal value of theta.
#
# We could also use the normal equation (X'X)^-1 * X'*y but that is less educational

# %%
m, _ = np.shape(X)
X = np.concatenate([np.ones((m, 1)), X], axis=1)
theta = np.zeros((2, 1))

def cost(theta, X, y):
    error = (X.dot(theta) - y)
    return error.T.dot(error) / (2 * m)

def grad(alpha, theta, m, X, y): 
    error = (X.dot(theta) - y)
    theta -= (alpha/m) * error.T.dot(X).T
    return theta

iterations = 300
alpha = 0.01
costs = []
for step in range(iterations):
    if step % 10 == 0:
        costs.append(cost(theta, X, y)[0, 0])
    theta = grad(alpha, theta, m, X, y)

# %% [markdown]
# # The cost curve as we do gradient descent:

# %%
plt.plot(costs)

# %% [markdown]
# # We now have a linear model of the data:

# %%
model = lambda x: x.dot(theta)
plt.plot(X[:, 1], y, 'rx')
plt.plot(X[:, 1], model(X))

# %%
size = 100
theta = np.zeros((2, 1))
theta0_vals = np.zeros((size, size))
theta1_vals = np.zeros((size, size))
J_vals = np.zeros((size, size))
zero_steps = np.linspace(-40, 40, size)
one_steps = np.linspace(-8.5, 11.5, size)

for zero_index, theta0 in enumerate(zero_steps):
    for one_index, theta1 in enumerate(one_steps):
        theta[0, 0] = theta0
        theta[1, 0] = theta1
        theta0_vals[zero_index, one_index] = theta0
        theta1_vals[zero_index, one_index] = theta1
        J_vals[zero_index, one_index] = cost(theta, X, y)

# %% [markdown]
# # The square-error surface of our linear model:

# %%
from mpl_toolkits.mplot3d import axes3d

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_wireframe(theta0_vals, theta1_vals, J_vals, rstride=5, cstride=5)
plt.show()


# It seems like ipython can only either display inline figures or 
# interactive figure in separate windows, but not both in a notebook. :(

# %%
from matplotlib import cm

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
cset = ax.contour(theta0_vals, theta1_vals, J_vals, 5, cmap=cm.coolwarm)
ax.clabel(cset, fontsize=9, inline=1)

plt.show()

# %% [markdown]
# # IsoErrors
# Each curve on the above plot is an 'isoerror' curve -- it represents theta values which give the same squared error.

# %%
# https://stackoverflow.com/questions/1560424/how-can-i-get-the-x-y-values-of-the-line-that-is-ploted-by-a-contour-plot-mat
iso_errors = cset.collections[0]
iso_errors.get_paths()
# error_curves = dict(zip(cset.levels, iso_errors.get_paths()))
error_curves = dict(zip(cset.levels, [collection.get_paths() for collection in cset.collections]))

# %%
# first = error_curves[7500][0]
# foo = list(first.iter_segments())
# plt.plot([f[0] for f in foo])

print error_curves.keys()
for curve_list in error_curves.values():
    print len(curve_list)
    for curve in curve_list:
        curve_segments = curve.iter_segments()
        plt.plot([segment[0] for segment in curve_segments])
# Out:
# [3000.0, 4500.0, 6000.0, 1500.0, 7500.0]
# 2
# 2
# 2
# 2
# 1

# %%
curve_list = error_curves[3000]
curve_list
print len(curve_list)
curve = curve_list[0]
segments = list(curve.iter_segments())
plt.plot([point[0] for point in segments])
t1 = np.zeros((3, 1))
print segments[0][0]
print segments[-1][0]

t1[0, 0] = np.matrix(segments[0][0][0])
t1[1, 0] = np.matrix(segments[0][0][1])
print cost(t1[0:2, :], X, y)

t2 = np.zeros((3, 1))
t2[0, 0] = np.matrix(segments[-1][0][0])
t2[1, 0] = np.matrix(segments[-1][0][1])
print cost(t2[0:2, :], X, y)
# Out:
# 2
# [-0.05543555 -0.01280113]
# [-0.01758749 -0.03968559]
# [[ 33.2467096]]
# [[ 34.83799692]]

# %%
transform = cset.get_transform()

new_t1 = t1.T.dot(transform.frozen()).T[0:2, :]

new_t2 = t2.T.dot(transform.frozen()).T[0:2, :]

print cost(new_t1, X, y)
print cost(new_t2, X, y)
# Out:
# [[ 35611.52501768]]
# [[ 134888.47182581]]

# %%
print transform.transform

# %%
print transform.frozen
